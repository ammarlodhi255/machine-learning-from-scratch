# %%
import pandas as pd
import numpy as np

df = pd.read_csv('./datasets/food-consumption.csv')
pd.set_option('display.max_columns', df.shape[1])
df.head(5)
# Out:
#    Country  Real coffee  Instant coffee  Tea  Sweetener  Biscuits  \
# 0  Germany           90              49   88       19.0      57.0
# 1    Italy           82              10   60        2.0      55.0
# 2   France           88              42   63        4.0      76.0
# 3  Holland           96              62   98       32.0      62.0
# 4  Belgium           94              38   48       11.0      74.0
#
#    Powder soup  Tin soup  Potatoes  Frozen fish  Frozen veggies  Apples  \
# 0           51        19        21           27              21      81
# 1           41         3         2            4               2      67
# 2           53        11        23           11               5      87
# 3           67        43         7           14              14      83
# 4           37        23         9           13              12      76
#
#    Oranges  Tinned fruit  Jam  Garlic  Butter  Margarine  Olive oil  Yoghurt  \
# ...

# %%
# Checking the presence and count of null values:
df.isnull().sum()
# Out:
# Country           0
# Real coffee       0
# Instant coffee    0
# Tea               0
# Sweetener         1
# Biscuits          1
# Powder soup       0
# Tin soup          0
# Potatoes          0
# Frozen fish       0
# Frozen veggies    0
# Apples            0
# Oranges           0
# Tinned fruit      0
# Jam               0
# Garlic            0
# Butter            0
# Margarine         0
# Olive oil         0
# Yoghurt           1
# Crisp bread       0
# dtype: int64

# %%
X = df.iloc[:, 1:]
y = df.iloc[:, 0]
